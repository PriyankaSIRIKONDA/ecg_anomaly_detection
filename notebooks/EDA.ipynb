# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# Set random seed for reproducibility
np.random.seed(42)

# Load the data from your specific location
data_path = r"C:\Users\DELL\Downloads\mitbih_train.csv"
df = pd.read_csv(data_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1]  # All columns except last
y = df.iloc[:, -1]   # Last column is label

# %%
# 1. Data Overview
print("Dataset Structure:")
print("\nData shape:", X.shape)
print("\nClass distribution:")
class_counts = pd.Series(y).value_counts()
print(class_counts)

# Calculate anomaly rate
normal_count = (y == 0).sum()
total_count = len(y)
anomaly_rate = (total_count - normal_count) / total_count * 100
print(f"\nAnomaly rate: {anomaly_rate:.2f}%")
# Out:
# Dataset Structure:
#
# Data shape: (87554, 187)
#
# Class distribution:
# 187
# 0.0    72471
# 4.0     6431
# 2.0     5788
# 1.0     2223
# 3.0      641
# Name: count, dtype: int64
#
# Anomaly rate: 17.23%

# %%
# 2. Visualize Sample Beats
plt.figure(figsize=(15, 10))
for i in range(5):  # Plot 5 different types of beats
    # Get a sample of each class
    sample_idx = y[y == i].index[0]
    plt.subplot(5, 1, i+1)
    plt.plot(X.iloc[sample_idx])
    plt.title(f'Class {i} Beat')
    plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 3. Time Series Analysis
# Plot multiple normal beats
plt.figure(figsize=(15, 5))
normal_beats = X[y == 0].iloc[:5]
for i in range(5):
    plt.plot(normal_beats.iloc[i], label=f'Beat {i+1}')
plt.title('Multiple Normal Beats')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 4. Statistical Analysis
print("\nStatistical Analysis:")
print("\nNormal beats statistics:")
print(X[y == 0].describe())

print("\nAnomaly beats statistics:")
print(X[y != 0].describe())
# Out:
# Statistical Analysis:
#
# Normal beats statistics:
#                 0             1             2             3             4    \
# count  72471.000000  72471.000000  72471.000000  72471.000000  72471.000000
# mean       0.915356      0.778014      0.403563      0.177536      0.164311
# std        0.211878      0.196904      0.214232      0.165603      0.131844
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.943983      0.716837      0.240857      0.038462      0.075075
# 50%        0.997368      0.832370      0.409226      0.131818      0.132964
# 75%        1.000000      0.910388      0.556351      0.281046      0.219796
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 5             6             7             8             9    \
# count  72471.000000  72471.000000  72471.000000  72471.000000  72471.000000
# mean       0.180612      0.180137      0.180581      0.183188      0.188259
# std        0.139403      0.155562      0.162569      0.165199      0.166272
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.082664      0.067416      0.061125      0.059567      0.063158
# 50%        0.141689      0.132479      0.127950      0.132584      0.138021
# 75%        0.249513      0.263309      0.268587      0.273053      0.277662
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...           177           178           179           180  \
# count  ...  72471.000000  72471.000000  72471.000000  72471.000000
# mean   ...      0.003115      0.002759      0.002444      0.002190
# std    ...      0.035021      0.032186      0.029383      0.027787
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      0.966851      1.000000
#
#                 181           182           183           184           185  \
# count  72471.000000  72471.000000  72471.000000  72471.000000  72471.000000
# mean       0.001984      0.001809      0.001656      0.001446      0.001250
# std        0.026171      0.024636      0.023730      0.022135      0.020098
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      0.979339      1.000000      1.000000      0.977974
#
#                 186
# count  72471.000000
# mean       0.001166
# std        0.019381
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 187 columns]
#
# Anomaly beats statistics:
#                 0             1             2             3             4    \
# count  15083.000000  15083.000000  15083.000000  15083.000000  15083.000000
# mean       0.770258      0.662769      0.522035      0.418831      0.378019
# std        0.322141      0.297199      0.260361      0.261687      0.246284
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.708270      0.503367      0.324215      0.201858      0.172229
# 50%        0.914062      0.737828      0.527273      0.420420      0.334351
# 75%        1.000000      0.911765      0.751079      0.600000      0.567132
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 5             6             7             8             9    \
# count  15083.000000  15083.000000  15083.000000  15083.000000  15083.000000
# mean       0.353523      0.329154      0.303594      0.273182      0.237584
# std        0.231150      0.224194      0.206988      0.182914      0.172296
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.147798      0.121073      0.121885      0.122092      0.107678
# 50%        0.337979      0.335681      0.298925      0.253837      0.196970
# 75%        0.528777      0.488622      0.445978      0.394850      0.314187
# max        1.000000      1.000000      1.000000      0.979381      0.973958
#
#        ...           177           178           179           180  \
# count  ...  15083.000000  15083.000000  15083.000000  15083.000000
# mean   ...      0.016833      0.015911      0.015120      0.014386
# std    ...      0.081287      0.078721      0.077474      0.075501
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#                 181           182           183           184           185  \
# count  15083.000000  15083.000000  15083.000000  15083.000000  15083.000000
# mean       0.013366      0.012678      0.012195      0.011752      0.011088
# std        0.072622      0.070824      0.069517      0.067704      0.065186
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 186
# count  15083.000000
# mean       0.010694
# std        0.063530
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 187 columns]

# %%
# 5. Pattern Analysis
# Calculate autocorrelation for a normal beat
normal_beat = X[y == 0].iloc[0]
autocorr = np.correlate(normal_beat, normal_beat, mode='full')
autocorr = autocorr[len(autocorr)//2:]

plt.figure(figsize=(10, 5))
plt.plot(autocorr)
plt.title('Autocorrelation of Normal Beat')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()

# %%
# 6. Key Findings
print("\nKey Findings:")
print("1. Data Characteristics:")
print(f"   - Total beats: {len(y)}")
print(f"   - Number of features: {X.shape[1]}")
print(f"   - Number of classes: {len(np.unique(y))}")

print("\n2. Time Patterns:")
print("   - Each beat is 187 samples long")
print("   - Clear periodic patterns")
print("   - Different morphologies for different classes")

print("\n3. Anomaly Characteristics:")
print(f"   - Anomaly rate: {anomaly_rate:.2f}%")
print("   - Multiple types of anomalies")
print("   - Distinct patterns for each anomaly type")

print("\n4. Anomaly Detection Considerations:")
print("   - Need to account for beat morphology")
print("   - Consider temporal patterns")
print("   - Look for specific waveform characteristics")
# Out:
# Key Findings:
# 1. Data Characteristics:
#    - Total beats: 87554
#    - Number of features: 187
#    - Number of classes: 5
#
# 2. Time Patterns:
#    - Each beat is 187 samples long
#    - Clear periodic patterns
#    - Different morphologies for different classes
#
# 3. Anomaly Characteristics:
#    - Anomaly rate: 17.23%
#    - Multiple types of anomalies
#    - Distinct patterns for each anomaly type
#
# 4. Anomaly Detection Considerations:
#    - Need to account for beat morphology
#    - Consider temporal patterns
#    - Look for specific waveform characteristics
